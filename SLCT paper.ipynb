# %%
from subprocess import call,Popen,PIPE,check_output
import shlex

# %% [markdown]
# ### using the c program itself inside python
# the name of C file is SLCT giving it command and retreiving the output after running the file

# %%
n='2%' # cluster size

# %%
cmd=r"~/Downloads/slct ./Firewall\ Log/fw.log-20180401_aa_aa -s {}".format(n)
cmd=shlex.split(cmd)

# %%
output=check_output(cmd).decode()

# %%
print output
# Out:
# * proxy.pune.cdac.in date=2018-03-31 * devname=FG800C3G11614133 devid=FG800C3913802529 logid=0000000013 type=traffic subtype=forward level=notice vd=root srcip=10.208.2.70 srcport=137 srcintf="wan1" dstip=10.208.3.255 dstport=137 dstintf="port3" * status=deny policyid=0 dstcountry="Reserved" srccountry="Reserved" trandisp=noop service=137/udp proto=17 duration=0 sentbyte=0 rcvdbyte=0 crscore=2432696350 craction=131072
# Support: 317
#
# ...

# %% [markdown]
# *Cyber attacks are assumed to be anomalous.<br>
# Normal activity are more harder to describe than malicious activity
# Cyber attacks are also often automated, making the activity observed very predictable. This automation, which can make an attack more effective and more destructive, can therefore be used to our advantage. *<br>
# So for a specified time window of activity, clusters are formed

# %% [markdown]
# One of the problems for clustering is normal activity as well as malicious activity will form clusters, Assuming most activity in a cluster will be either malicious or normal, the problem simplifies to differentiating between clusters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We are using whole of log as feature to prevent the bias created when using only selected part of the log as features
